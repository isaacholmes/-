# %%
print(__doc__)

# Import the necessary modules and libraries
import numpy as np
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt

# Create a random dataset
rng = np.random.RandomState(1)
X = np.sort(5 * rng.rand(80, 1), axis=0)
y = np.sin(X).ravel()
y[::5] += 3 * (0.5 - rng.rand(16))

# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth=2)
regr_2 = DecisionTreeRegressor(max_depth=5)
regr_1.fit(X, y)
regr_2.fit(X, y)

# Predict
X_test = np.arange(0.0, 5.0, 0.01)[:, np.newaxis]
y_1 = regr_1.predict(X_test)
y_2 = regr_2.predict(X_test)

# Plot the results
plt.figure()
plt.scatter(X, y, s=20, edgecolor="black",
            c="darkorange", label="data")
plt.plot(X_test, y_1, color="cornflowerblue",
         label="max_depth=2", linewidth=2)
plt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
# Out:
# Automatically created module for IPython interactive environment

# %%
from IPython.display import Image  
from sklearn import tree
import pydotplus 
import os
os.environ["PATH"] += os.pathsep + 'C:/Users/IsaacHolmes/Desktop/release/bin/'  
#regr_1 和regr_2
dot_data = tree.export_graphviz(regr_2, out_file=None,  #regr_1 是对应分类器
                         feature_names=['x'],   #对应特征的名字
                         class_names=['y'],    #对应类别的名字
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data)  
graph.write_png('example.png')    #保存图像
Image(graph.create_png())

# %%
from sklearn import tree
import numpy as np
import urllib

# %%
X = [[0,0],[1,1]]
Y = [0,1]
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X,Y)

# %%
clf.predict([[2.,2.]])
# Out:
# array([1])

# %%
clf.predict_proba([[2., 2.]])
# Out:
# array([[0., 1.]])

# %%
data = np.loadtxt('C:\Users\IsaacHolmes\Desktop\pfm.txt')
x = data[:,0:29]
y = data[:,30]

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(x, y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-50a578c36925> in <module>()
#       1 clf = tree.DecisionTreeClassifier()
# ----> 2 clf = clf.fit(x, y)
#
# C:\Users\IsaacHolmes\AppData\Roaming\Python\Python27\site-packages\sklearn\tree\tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     799             sample_weight=sample_weight,
#     800             check_input=check_input,
# --> 801             X_idx_sorted=X_idx_sorted)
#     802         return self
#     803
#
# C:\Users\IsaacHolmes\AppData\Roaming\Python\Python27\site-packages\sklearn\tree\tree.pyc in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     138
#     139         if is_classification:
# --> 140             check_classification_targets(y)
#     141             y = np.copy(y)
#     142
#
# ...

# %%
with open("pfm.dot",'w') as f:
    f = tree.export_graphviz(clf,out_file=f)

# %%
import os
os.unlink('pfm.dot')

# %%
import pydotplus
dot_data = tree.export_graphviz(clf,out_file = None)
graph = pydotplus.graph_from_dot_data(dot_data)
graph.write_pdf('pfm.pdf')
# Out:
# True

# %%
clf.predict(x[:1,:])
# Out:
# array([0.])

# %%
clf.predict_proba(x[:1,:])
# Out:
# array([[1., 0.]])
